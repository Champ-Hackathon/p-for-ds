# %% [markdown]
# <a href="https://colab.research.google.com/github/Champ-Hackathon/p-for-ds/blob/main/PDS_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:Nitesh yadav
# Class:SYIT
# Roll No:S050
# PDS 7
# Date:02/09/2026

# %% [markdown]
# **A. Write a Python program to create a scatter plot of Age and Height of 5 students.**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([15,20,21,25,26])
y = np.array([180,170,145,156,160])

plt.scatter(x, y)
plt.xlabel("Age")
plt.ylabel("Height in cm")
plt.title("Scatter Plot Age and Height")
plt.show()

# %% [markdown]
# B. **Write a Python program to create a bar chart showing marks of 5 students.**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Nitesh", "Rahul", "Amit", "Kaushal","Sunny"])
y = np.array([80, 88, 78, 65,70])

plt.bar(x, y, color = "red")
plt.xlabel("Student")
plt.ylabel("Marks")
plt.title("Bar chart Student and Marks")
plt.show()

# %% [markdown]
# **C. Write a Python program to create a histogram showing the distribution of marks of 10 students.**

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([50, 80, 70, 75, 78, 82, 81, 83, 90, 65])

plt.hist(y)
plt.xlabel("Marks")
plt.ylabel("Number of Students")
plt.title("Histogram of Student Marks")
plt.show()

# %% [markdown]
# **D. Write a Python program to create a pie chart showing the number of students in different courses.**

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Bsc.IT", "Bsc.Biotech", "Bsc.CS", "BMMAC"]

plt.pie(y, labels = mylabels)
plt.title("Pie chart of Student Course")
plt.show()

# %% [markdown]
# **E. Write a Python program to create a bar chart showing sales of 5 different products.**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Parle", "James", "Phone", "Airbirds","Bluetoth"])
y = np.array([80, 88, 78, 65,70])

plt.barh(x, y, color = "red")
plt.xlabel("Products")
plt.ylabel("Quantity")
plt.title("Bar chart sales product")
plt.show()
