# %% [markdown]
# <a href="https://colab.research.google.com/github/Champ-Hackathon/p-for-ds/blob/main/PDS_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Nitesh yadav
# Class: SYIT
# Roll no: S050
# Date: 19/08/2026
# PDS 6

# %% [markdown]
# 6a. Write a Python program to import a CSV dataset using Pandas and
# display the first 5 and last 5 records.

# %%
import pandas as pd

# %%
df = pd.read_csv("Students.csv")

# %% [markdown]
# Print top 5 values

# %%
print(df.head())
# Out:
#    Roll No     Name Department  Marks  Attendance
# 0      101   Nitesh     BSc IT     90          99
# 1      102    Rahul     BSc CS     85          90
# 2      103  Kaushal     BSc IT     88          92
# 3      104      Raj     BSc CS     92          78
# 4      105   Roshan     BSc IT     65          80

# %% [markdown]
# Print last 5 values

# %%
print(df.tail())
# Out:
#    Roll No     Name Department  Marks  Attendance
# 0      101   Nitesh     BSc IT     90          99
# 1      102    Rahul     BSc CS     85          90
# 2      103  Kaushal     BSc IT     88          92
# 3      104      Raj     BSc CS     92          78
# 4      105   Roshan     BSc IT     65          80

# %% [markdown]
# 6b. Write a Python program to analyze the dataset by displaying the number of
# rows and columns, column names, data types, and basic statistical information. **bold text**

# %%
print(df.shape)
# Out:
# (5, 5)

# %% [markdown]
# Filter Dataset

# %%
print(df.columns)
# Out:
# Index(['Roll No', 'Name', 'Department', 'Marks', 'Attendance'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Roll No        int64
# Name          object
# Department    object
# Marks          int64
# Attendance     int64
# dtype: object

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    Roll No     Name Department  Marks  Attendance
# 0      101   Nitesh     BSc IT     90          99
# 1      102    Rahul     BSc CS     85          90
# 2      103  Kaushal     BSc IT     88          92
# 3      104      Raj     BSc CS     92          78
# 4      105   Roshan     BSc IT     65          80>

# %% [markdown]
# 6c. Write a Python program to filter records from the dataset using

# %%
result = df[df["Attendance"]>=80]
print(result)
# Out:
#    Roll No     Name Department  Marks  Attendance
# 0      101   Nitesh     BSc IT     90          99
# 1      102    Rahul     BSc CS     85          90
# 2      103  Kaushal     BSc IT     88          92
# 4      105   Roshan     BSc IT     65          80

# %% [markdown]
# 6d. Write a Python program to sort the dataset based on a selected column
# and display the top 5 records.

# %%
result = df.sort_values("Marks")
print(result)
# Out:
#    Roll No     Name Department  Marks  Attendance
# 4      105   Roshan     BSc IT     65          80
# 1      102    Rahul     BSc CS     85          90
# 2      103  Kaushal     BSc IT     88          92
# 0      101   Nitesh     BSc IT     90          99
# 3      104      Raj     BSc CS     92          78

# %% [markdown]
# 6e. Write a Python program to perform data analysis on the dataset by
# finding the maximum, minimum, average, and total values of a numerical
# column.

# %%
print("Maximum Marks ",df["Marks"].max())
print("Minimum Marks ",df["Marks"].min())
print("Mean Marks ",df["Marks"].mean())
print("Median Marks ",df["Marks"].median())
print("Sum Marks ",df["Marks"].sum())
# Out:
# Maximum Marks  92
# Minimum Marks  65
# Mean Marks  84.0
# Median Marks  88.0
# Sum Marks  420
